# %%
import tweepy
from textblob import TextBlob
import csv


# Step 1 - Authenticate
consumer_key= 'PGKQuYtBwUa8ih5iBy80umlIj'
consumer_secret= 'u2I5mh4llehglJt05RSN2lXnpDxqiZT3dQ0yMnsi9VW5itY2IC'

access_token='103894086-gQyAd64U82fU1jNW9F0vyaasetqSr0VHyqzHuzET'
access_token_secret='Q6eAXmd1Qry9jq82OfmPPyeWIblwY7hnnwd97he7GZL2I'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets
public_tweets = api.search('#GoBackModi')



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

for tweet in public_tweets:
    print(tweet.text)
        
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment, '\n')   
print("")

#get public tweet in list
sentance_to_analyse = [[tweet.text]for tweet in public_tweets]

#Make row of tweets
with open('sentiment.csv', 'w') as csvfile:
    file = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_ALL)
    file.writerow(['Tweet', 'Polarity'])
    file.writerows(sentance_to_analyse)

#perform sentiment analysis on tweets    
with open('sentiment.csv', 'r') as f:
    rows = csv.reader(f)
    sentiment_of_tweet = [["Positive"] if TextBlob(r[0]).sentiment.polarity >= 0 else ["Negative"] for r in rows]

'''
 csv doesnt support write column because variable-length lines are not really 
 supported on most filesystems. What you should do instead is collect all the 
 data in lists, then call zip() on them to transpose them after. 
'''
#collect data in list-[], tupple-()
data = [(sentance_to_analyse),(sentiment_of_tweet)]
zipp = zip(*data)
#print(zipp)

#write tweet and its sentiment     
with open('sentiment.csv', 'w') as csvfile:
    file = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_ALL)
    
    file.writerow(['Tweet', 'Polarity'])
    file.writerows(zipp)
# Out:
# RT @maithriim: Karma is a bitchன்னு இவ்வளவு சீக்கிரம் நிரூபணம் ஆகும்னு அமித் ஷாவே நினைத்திருக்க மாட்டார். வாழ்க்கை ஒரு வட்டம் தான்.#GoBackM…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# #IndiaVsModi Why I feel like this trend is last more than #GoBackModi hashtag.... they india hate modi so much
# Sentiment(polarity=-0.02500000000000001, subjectivity=0.4166666666666667)
#
# @sumanthraman Getting interesting..... May be Soon, #GoBackModi will be changed as #WelcomeModi  😃😂
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# RT @maithriim: Karma is a bitchன்னு இவ்வளவு சீக்கிரம் நிரூபணம் ஆகும்னு அமித் ஷாவே நினைத்திருக்க மாட்டார். வாழ்க்கை ஒரு வட்டம் தான்.#GoBackM…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @maithriim: Karma is a bitchன்னு இவ்வளவு சீக்கிரம் நிரூபணம் ஆகும்னு அமித் ஷாவே நினைத்திருக்க மாட்டார். வாழ்க்கை ஒரு வட்டம் தான்.#GoBackM…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @Th_Robot: அண்ணைக்கு #GoBackModi சொன்னது?
#
# 200 ரூபாய்க்கு சார்.
#
# அப்ப நாளைக்கு #WelcomeAmitShah சொல்ல போறது
#
# அதுவும் 200 ரூபாய்க்கு சார்…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# அண்ணைக்கு #GoBackModi சொன்னது?
#
# 200 ரூபாய்க்கு சார்.
#
# அப்ப நாளைக்கு #WelcomeAmitShah சொல்ல போறது
#
# அதுவும் 200 ரூபா… https://t.co/RlZQCWpHJV
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @PTTVOnlineNews நீங்க என்னதான் பேசினாலும் நாங்க #GoBackModi மட்டுந்தான்...உங்க நடிப்பு எங்களுக்குத் தெரியாதா என்ன!
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @maithriim: Karma is a bitchன்னு இவ்வளவு சீக்கிரம் நிரூபணம் ஆகும்னு அமித் ஷாவே நினைத்திருக்க மாட்டார். வாழ்க்கை ஒரு வட்டம் தான்.#GoBackM…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ThimiranVJ: A single image that describes entire issue happening right now in Tamilnadu !
# #GoBackModi https://t.co/DiI1JolHux
# Sentiment(polarity=0.09523809523809523, subjectivity=0.4583333333333333)
#
# @PTTVOnlineNews சாமி நீ தலைகீழாக நின்று தண்ணி குடிச்சாலும், நாங்க #GoBackModi ன்னுதான் சொல்லுவோம்!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @jhambt: #GoBackAmitShah #gobackmodi ட்வீட் போட்டு , கருப்புகொடி காட்டி சீன் போட்ட உ.பிஸ்...காவியோட கூட்டணி சேர்ந்தா என்ன அர்த்தம் தெரி…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# #GoBackAmitShah #gobackmodi ட்வீட் போட்டு , கருப்புகொடி காட்டி சீன் போட்ட உ.பிஸ்...காவியோட கூட்டணி சேர்ந்தா என்ன அர்த்தம் தெரியுமா. 😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @tamilamizhthu: நேற்று #Gobackmodi
#
# இன்று #WelcomeBackAmitshah
#
# திமுக உபீஸ் 😂😂 | #DMKwedsBJP https://t.co/YEHlvbcNwO
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @Satheesh_2017: வெடி சத்தமா
#
# பாஜக வெடிக்கிறதெல்லாம் ஊசி பட்டாசு தான்😂😂😂
#
# Tag போடுற மூஞ்சிங்கள பாரு
#
#  #Gobackmodi இந்த tag worldwide tre…
# Sentiment(polarity=0.0, subjectivity=0.0)
