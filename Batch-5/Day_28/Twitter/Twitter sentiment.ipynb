# %%
import tweepy
from textblob import TextBlob
import csv


# Step 1 - Authenticate
consumer_key= 'PGKQuYtBwUa8ih5iBy80umlIj'
consumer_secret= 'u2I5mh4llehglJt05RSN2lXnpDxqiZT3dQ0yMnsi9VW5itY2IC'

access_token='103894086-gQyAd64U82fU1jNW9F0vyaasetqSr0VHyqzHuzET'
access_token_secret='Q6eAXmd1Qry9jq82OfmPPyeWIblwY7hnnwd97he7GZL2I'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets
public_tweets = api.search('Modi')



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

for tweet in public_tweets:
    print(tweet.text)
        
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment, '\n')   
print("")

#get public tweet in list
sentance_to_analyse = [[tweet.text]for tweet in public_tweets]

#Make row of tweets
with open('sentiment.csv', 'w') as csvfile:
    file = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_ALL)
    file.writerow(['Tweet', 'Polarity'])
    file.writerows(sentance_to_analyse)

#perform sentiment analysis on tweets    
with open('sentiment.csv', 'r') as f:
    rows = csv.reader(f)
    sentiment_of_tweet = [["Positive"] if TextBlob(r[0]).sentiment.polarity >= 0 else ["Negative"] for r in rows]

'''
 csv doesnt support write column because variable-length lines are not really 
 supported on most filesystems. What you should do instead is collect all the 
 data in lists, then call zip() on them to transpose them after. 
'''
#collect data in list-[], tupple-()
data = [(sentance_to_analyse),(sentiment_of_tweet)]
zipp = zip(*data)
#print(zipp)

#write tweet and its sentiment     
with open('sentiment.csv', 'w') as csvfile:
    file = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_ALL)
    
    file.writerow(['Tweet', 'Polarity'])
    file.writerows(zipp)
# Out:
# RT @DrAMSinghvi: #RG abs rite tht cong as party not involved in #1984riots Individual aberrations heavily condemned by cong. Several-Tytler…
# Sentiment(polarity=-0.1, subjectivity=0.45)
#
# #ArnabGoswami is the worst and shameless media person I ever seen.. He is a just a unofficial spokesperson of BJP-R… https://t.co/7WKaV22dmy
# Sentiment(polarity=-1.0, subjectivity=1.0)
#
# RT @rupagulab: So ironic when Modi Bhakts call RG dumb but aggressively defend the most foolish PM ever. DeMonetisation was like cow-pee-cu…
# Sentiment(polarity=0.10833333333333334, subjectivity=0.6333333333333333)
#
# RT @TN_PYC: Right now, it’s time for our PM Modi ji to open his mouth, &amp; criticize &amp; act against these incidents of women harassment unless…
# Sentiment(polarity=0.14285714285714285, subjectivity=0.5178571428571428)
#
# RT @rosvlba: ricordatevi che ‘ascoltare’ e ‘sentire’ sono due modi diversi di dare attenzione
# Sentiment(polarity=-0.125, subjectivity=0.375)
#
# RT @vidya7281: Rahul gandhi was 14yrs 1984
# But what about 2002 riots Modi was at age of 50/ 51 Now who is blamed for this ?@sambitswaraj @…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @TheUnRealTimes: Congress should insist on BJP paying at least half (if not full) of the expenses incurred in sending Rahul Gandhi abroa…
# Sentiment(polarity=-0.21388888888888888, subjectivity=0.37222222222222223)
#
# RT @ANI: The triple talaq bill was passed in Lok Sabha but could not be passed in the Rajya Sabha. But, I would like to assure Muslim women…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# 'தமிழ் மொழியால் தேசம் பெருமை கொள்கிறது' - மான் கி பாத் நிகழ்ச்சியில் நெகிழ்ந்த மோடி!
# #MannKiBaat #PMModi #Tamil… https://t.co/XELcpIqZjs
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @cuttingedge2019: World knows India under fake Gandhis been the most corrupt till PM Modi arrived on the scene &amp; he's doing wonders to d…
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.8333333333333334)
#
# RT @satishacharya: Petrol pumps are pressurised to display PM Modi's photos!
# @sifydotcom cartoon https://t.co/58MWPTGNm5
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Pm modi Mann ki baat August 2018https://youtu.be/biNpdv13I88
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @sumanthraman: If @RahulGandhi is pappu and is a failed politician then surely he poses no threat to Modi, right? Then why go on &amp; on &amp;;…
# Sentiment(polarity=0.09523809523809523, subjectivity=0.5748677248677249)
#
# @Marathi_Tweets @BedreBandu @swaruprahane88 @ImLB17 @BotMarathi @Dev_Fadnavis @YuvrajSambhaji @NCPspeaks @INCIndia… https://t.co/MrozAz4DEp
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @reviewero: Rahul Gandhi basically said I don't know anything about anything but Modi is definitely wrong about everything ..and that su…
# Sentiment(polarity=-0.5, subjectivity=0.9)
