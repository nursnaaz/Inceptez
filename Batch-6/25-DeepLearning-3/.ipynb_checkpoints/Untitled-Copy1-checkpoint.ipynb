# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 2s 3us/step
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# Epoch 1/60
# 200285/200285 [==============================] - 111s 555us/step - loss: 1.9852
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ain of our invention just here, the
# doma"
# ain of our invention just here, the
# doman which wither and in a prosented the condition of the self-ressions of a prosented to a the and the self-respection of a presented the self-resting and most and canser and conception of the self and the will and the will a prissent of a most and propless of the most self-ristount wither and the self and destrection of the self-rision of the self-rises and self-ristence of a most and world and and
# ----- diversity: 0.5
# ----- Generating with seed: "ain of our invention just here, the
# doma"
# ain of our invention just here, the
# doman and remandor the here and from and the serstian and head of himself and master the have and some some the higher and philosophers and simplife watie and condition and the world wither in the conditient self-respection and most feeling the inition of a perhaps of a promiscemptive and be the conception of a menisting with in the spirity of was a prising can first presen in it is a mas or the and c
# ----- diversity: 1.0
# ----- Generating with seed: "ain of our invention just here, the
# doma"
# ain of our invention just here, the
# domating
# men of a find and mether adven affater
# wnowed "oun we "peruarn forled, foundnesspy ani
# crrme most frem is the
# rulond of an of
# diswire thing--a
# lvoloniao.
# sukelvficely of relugher do injunce of lopker that every as a perhapsoppounent make such to
# whate to the morality are moral are
# dambate of to among a flivil trangmily of eaker
# san sysility aftepthing patcalsime that i ponounce of sen
# a itsel
# ----- diversity: 1.2
# ----- Generating with seed: "ain of our invention just here, the
# doma"
# ain of our invention just here, the
# domain fanseif hugo attains comes indisye phowoguous the otterly as
# husa ornerly ageir, contercfid aad
# domeniatiouaw to trempticeare h o highouln like-the
#  bee on we mand the call have thew has not be a de trat inso-tadiy) whacespesule in which nly futhard towle will! no
# felusat,, we will in remanision, men
# or baim. and i bem trets: yverfhing my adem in a
# seryes, atwaried, ar" tr be nemesned of
# remedi
# Epoch 2/60
# 200285/200285 [==============================] - 100s 499us/step - loss: 1.6335
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: ", which, even without our putting in mot"
# , which, even without our putting in motive and present to the present to the more to the present to the more to the speciently and the society to the world--the speciently to the present to the specient and and to the surposition of the great the self-distrust of the present to the present to the present to the contrainity of the contration of the self-contrary and to the stronged in the present to the present to the self-convention of
# ----- diversity: 0.5
# ----- Generating with seed: ", which, even without our putting in mot"
# , which, even without our putting in motive to the only a stronger.
#
#
#
#
#
#
#                         condition is an antial precepted to the soul the simuation of a
# some and to conception, and in one and artion. the form, to the permest and contrace to be preception of the tration to all power all indection of it is a mastination of herenger to seems and present of any and fear to the reperious hered as the self-stronged
# in the recignity t
# ----- diversity: 1.0
# ----- Generating with seed: ", which, even without our putting in mot"
# , which, even without our putting in mottics of all
# out of god"--bune cultuseour i
# to german "motives it enturater, in the stefe inis paisily with ever lang has understatiated and remation are that it of exunies-sysprecies
# me; would their
# his so only excrenies of toe so the proprace and pish the treets ratious and
# his lapent to that indeege present dounds as a ! peopled thas crumited
# upmerers to eyes, he doe the man who ha diviled remed
# ----- diversity: 1.2
# ----- Generating with seed: ", which, even without our putting in mot"
# , which, even without our putting in motherx fain, readitare whiths "ngmamil
# learn--eytings, of at the mory good to fast at i
# mettos
# there: naturianily on,
# and were
# god constine-clobilihy trughbre misnchile, but of
# the soci; ebrediedly to
# mean to ausable--casives and werenning to a higked--on this to
# preciels its mond mean die, with
# their freet praphifics towood ofsifnrate
# masker, yet the tire humt deabrenc
# just probownt." and religioua
# Epoch 3/60
# 200285/200285 [==============================] - 107s 535us/step - loss: 1.5461
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "s accompanied by a desire for some physi"
# s accompanied by a desire for some physical so the contrasimity of the spiritues of the contrasimis the most the superficition of the striving the stronger and contrations the stronger and self-trained the construction of the constitution of the soul in the still the present the most the contrasiming of the constrainion and most the most present of the constined to the most the present the present and conception of the present the contr
# ----- diversity: 0.5
# ----- Generating with seed: "s accompanied by a desire for some physi"
# s accompanied by a desire for some physical upon the present in the possible to fearing man which is a good in the former process and contrasiments, for the most the summaning the world say the fact that the supsemitation of the solition the can lighty and them. the construction of camming only a fill the prissess of the pratoristic must himself of manifices, there is the stronger who capshing in according and will and the something in
# ----- diversity: 1.0
# ----- Generating with seed: "s accompanied by a desire for some physi"
# s accompanied by a desire for some physicance of thems cause to wanne ofitroned consteris of which the crass and to sampatument,, to pre to likenarudant contriet of debpluated his still we herven
# not the fining as perhaps as from grotomences of the filless and deligioned within gooding presenvation the mostoces the belong them, the a ritanian, in the fact is greateness crue to highly is may do a pertain of
# althole
# not
# was timeod age in
# ----- diversity: 1.2
# ----- Generating with seed: "s accompanied by a desire for some physi"
# s accompanied by a desire for some physicish?hyly in a would be mudue in a applain only a moblesable,gance, spectunt to debre vclusionian of mankind.
#
# creain to adarnitily which amt
# in fhithevture it.
# no evologinable milgetouch,--, he per. an the team.
# the denocresie.--his tranicism,
# a, brow he in
# grokn thing pertamedm pataciean and probacs-worlad. it as rittieg-everychies obsernation, thried in
# orders, by mitgest of moarati are wilnis
# Epoch 4/60
# 200285/200285 [==============================] - 98s 488us/step - loss: 1.5025
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "se. to be sure, one must not resign ones"
# se. to be sure, one must not resign oneself the spirit as the power of the great and strength of the spirit and spirit of the spirit of the present the present the spirit the spirit of the strength of the consideration of the spirit of the words of the spirit of the spirit of the spirits of the strength of the prosong the proposed the spirit and the spirit of the strength of the strength of the spirits and strength of the spirit of the
# ----- diversity: 0.5
# ----- Generating with seed: "se. to be sure, one must not resign ones"
# se. to be sure, one must not resign oneself become the extend of a but the sensations of
# the striving and contempt and uniference of his could never reason of the power of the subtle
# supersitional prolitional intenus has wart and prestincting the become with the philosophers is the interprets the spirit that we do not a reality, a finally the call the most practication of the extinuation of the power for the seem of his distress, and wi
# ----- diversity: 1.0
# ----- Generating with seed: "se. to be sure, one must not resign ones"
# se. to be sure, one must not resign ones was shompness, have
# diflide--thought, mistended of her this.
#
# .       ry, that virtues hardly such not and swill
# that it is it is way make will--pumse det homemingbous in all suril that they
# ": no
# hand to this inkinding" be a extence to cours supribacfilled's
# an a
# impulseh man certainal
# oprest beler as regress.
# it ye does not die2ver of make to s necussion.=--oning that though the becond will so
# ----- diversity: 1.2
# ----- Generating with seed: "se. to be sure, one must not resign ones"
# se. to be sure, one must not resign ones belogy they xcaeln things forthouchewher
# out.
# that ho weople, so-adiaty have pants xide; i me
# agoneditamus.t i yeerest subtle; brankuid was clustom, againit for his nothiness in impitated tacking and finally science us"gate callasiseing--the sorp, romage of one needratel, dreams"? of hurture first eopetang! at the
# eyes have ap hasble yight at looks rea sap, to ""buce: liat undes him
# speems and sp
# Epoch 5/60
# 200285/200285 [==============================] - 106s 530us/step - loss: 1.4735
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "e
# possibility already conceded: but noth"
# e
# possibility already conceded: but nothing of the strive the conscience of the strive to the spirit to the strive the sense, and a stricted and world of the profounder that the soul of the soul and such a philosophy and strive the same disconting and the strive of the strive the same distrust in the soul and and interpreted the same profounded the spirit and as the spirit and strive and and conscience of the strength of the superstitio
# ----- diversity: 0.5
# ----- Generating with seed: "e
# possibility already conceded: but noth"
# e
# possibility already conceded: but nothing at the strength of a distrust and profounder to the superstition of the same a manifests of a profoundent and life, in the really the soul of a such a terd the canniness the most to the mind in the contemption of the more man is the strive and exceptions and considerable the does not not the spirit and penation of the stard that has been calling of a person in the render, on the disconding its
# ----- diversity: 1.0
# ----- Generating with seed: "e
# possibility already conceded: but noth"
# e
# possibility already conceded: but nothing in taithing, to which here forreadied preativisme of the less methorance to that is presumionation and foum
# physiocanter that whates of ace-munivality" are woman conceined, mylenes. the our neech of dickying. it as a remadment introcedly, and about what really really, that i hergits hors this hasmy
# to the nowed upobonitation, he is at the most vadies itself not say a recroved
# "mastser
# of plent
# ----- diversity: 1.2
# ----- Generating with seed: "e
# possibility already conceded: but noth"
# e
# possibility already conceded: but nothinc eality of religionation a wovenfer, as a dien te; in
# the interpreting ob inthiry enimhatoms forfrpoliness forth anowies us tholomiefued, in ndear?) that and in patists or have deattrod devain been menatitiblial etenness entirua others depled of a -compunsms of the vo becoment" only
# hony reforioly much
# is makes
# determine to powerfuld are enlighon.=--ama and philosophiphy, lutivation, and as
# ple
# Epoch 6/60
# 200285/200285 [==============================] - 115s 573us/step - loss: 1.4519
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "tion, this high sounding rhetoric which "
# tion, this high sounding rhetoric which is a strange the standard the passion of the standard the proceed to the mankind of the morality of the standard the morality of the spirit of the strange to the most desire the fame the sense, the standard to the standard the standard the standard the standard the same still the same time of the present, the spirit that there is a strange the senses the philosophers of the strange the man for the
# ----- diversity: 0.5
# ----- Generating with seed: "tion, this high sounding rhetoric which "
# tion, this high sounding rhetoric which all the same time to his among the mankind, and see the still the spirit there are all the distance, on the true of the passion that they is they the signification of the means of the been the time and still explanations of the deveres of the conscious the work of the speaks and ancient in the morality german in the deveres the most present the standary the higher that is the langing the spirit is
# ----- diversity: 1.0
# ----- Generating with seed: "tion, this high sounding rhetoric which "
# tion, this high sounding rhetoric which is a standelomy theret-goad, for the smowakists," athised
# many only
# when any indeviring that like of new curiosis
# that the nourial of the evidences to come of srute, to the unhertents for german
# higher anaring man side the genuine and and good brathed, smorty, as
# the conscitude himself, there is of any supersares the srevelt there is
# all morg usevis as this man brom the
# philosopher to the charm wo
# ----- diversity: 1.2
# ----- Generating with seed: "tion, this high sounding rhetoric which "
# tion, this high sounding rhetoric which theurical many engogrty of thein" ous
# aics to hepenis and fichowaring over olish secratifis must almost which we may reached
# posterity, that
# eron
# in their otherbow
# reprossume, owing, titerous by his own risi. -mather
# fine to hikness to
# sivele--to "husugnal to knatger according: "wispaming to the
# tody
# demonmanibger"s: he wistenct.--end bimilly in remain re
# exicuden qualitingeits odirared for abour
# Epoch 7/60
# 200285/200285 [==============================] - 105s 523us/step - loss: 1.4349
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "e brain which is most
# encroached upon in"
# e brain which is most
# encroached upon in the consequence of the standard the sense of the consequence of the sense, and a standard the sentimate and a spective of the standard the sense of the sentiment the same a standary the process of the sentiment of the standard to the same the sentimate the sense of the man world and the man world and an an a standance of the stance of the probably and a standary the sense, the concealed the god i
# ----- diversity: 0.5
# ----- Generating with seed: "e brain which is most
# encroached upon in"
# e brain which is most
# encroached upon indeed man probably corrumand to be sacrifice of the painful with the conteming and of the a morals a conclusion of which all the herself even the tempt of the god in the menstoperity, and by the concealed for the contemitation and and not can be more world and certain belief as some conceal that in our word among the confect to the sident their spirits and a not and the most process and morality of
# ----- diversity: 1.0
# ----- Generating with seed: "e brain which is most
# encroached upon in"
# e brain which is most
# encroached upon in a belief certain that, they have deeal person such a builtity han of the possibilly, and that condict of man, among those gol-dream instold and stypet and of this kishion
# for it by means of our result cruing and of his lives and it an
# the word vountation; it even concelt error henced
# then
# we already of destruction of the preasoring has do in his lifeed--soul
# among the da-poerspural virtue for the
# ----- diversity: 1.2
# ----- Generating with seed: "e brain which is most
# encroached upon in"
# e brain which is most
# encroached upon influent, perceivoling
# and a schory": the asaa'icalfact csjousianion han guded.
#
#
# orone--ray act than "kiom
# his crymoral, agays: in endears oneming of coselt is ual sid the remines with the spective in doubtful inavice mudim, authormial, floomy philosopher is does the seger hasfes lonamy that to is injurrate somet intpition e, ther-.nd
# . their drearn
# mome
# dust
# and appears; rand opters is therf would
# Epoch 8/60
# 200285/200285 [==============================] - 98s 491us/step - loss: 1.4212
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ded us, for the relic before which we we"
# ded us, for the relic before which we were the self-consequently and individual such a strongest of the suchicistic and such a statesman and the sense of the stards and such and soul and the interpresent and such a still the such a still the superstitions of the spective of the spectamed the self-consequently and individual and in the same moral of the self-do the such an and such a still to the superstrated the stards of the self-domai
# ----- diversity: 0.5
# ----- Generating with seed: "ded us, for the relic before which we we"
# ded us, for the relic before which we were state, he course the such a history and prominiousness, and in the deceive of the source in the consequently this conscious transle of their sident of the conscious and the prevains, and into the stands of they necessary and conception of the most self-such a constitutes and intercas possibility and apparable individual in his religion and their self-spective was be instent and enconseption the
# ----- diversity: 1.0
# ----- Generating with seed: "ded us, for the relic before which we we"
# ded us, for the relic before which we were therely, as his the
# last
# things but ir interpartive indeed, belo" cericifurdpuing thoughttory are coumpreed, away exactions of the prites and nature as a best delustable milpten that, it now rogaits. onogive much hir hear, to chartarishing "ornally without
# their has of reliatistow of morally, a propositions, they his
# bonth refined, owings  empors and conceptate theiss free orready of instinct
# ----- diversity: 1.2
# ----- Generating with seed: "ded us, for the relic before which we we"
# ded us, for the relic before which we were attaring, but do mighter ersities--upon lo tectured indwrade of life and
# febftencely enceount, suffer, coccaple which perishecy is
# tiged wanting dobhest e? and work that has wisely which "laughy. incergeians,
# have own end, threw for the conditive which it instance: griatirys subligionic cular as himself in really and slaves.bleoptition
# shives good triatic. ther bemoging and comminxience, andpoc
# Epoch 9/60
# 200285/200285 [==============================] - 99s 496us/step - loss: 1.4108
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ity, and
# love of power, which up till th"
# ity, and
# love of power, which up till the senses and something and and and the problem of the truth the senses to the german strange, and in the conceptions and even to the truth the conscience of the senses of the problem of the conscience of the senses and the senses of the conscience of the senses and still and intellectual man who has not a stronger and and and the intellectual fact, and the problem of the proses to the senses to a
# ----- diversity: 0.5
# ----- Generating with seed: "ity, and
# love of power, which up till th"
# ity, and
# love of power, which up till the ideas and and can into the good and for a considered to a senses and religion of the truth one more expression of the general that the object of the comproted and to himself and the contrastic and and man of the case for the senses of the truth a soul of the truth, and and the senses and constrain of all interpreten and individuals, that the breates itself in the to the consequence of the truth
# ----- diversity: 1.0
# ----- Generating with seed: "ity, and
# love of power, which up till th"
# ity, and
# love of power, which up till thing
# is the
# needs and fored--the old insides will
# saten man of itself,"orapparism of hy-undilnt and by this interpreten for every made the c to the dramx, enconsent usders or too loves upticality of others--so this turning withleten; one will to wate
# spiritury victs,
# knows not god himself and as hence this comp agether does not with
# their utwal means, wisht neverthce be a strength, will to wave in
# ----- diversity: 1.2
# ----- Generating with seed: "ity, and
# love of power, which up till th"
# ity, and
# love of power, which up till the peincely rew--here, fundamental and most dimaroorian does neelect bsudeunt,,
# the formaled pietaniced from the catements;
# hocoubles: showessevence,
# valo-trepering, if quastedly and "embrangs.
#
# slish in ancesptedishturk mose distuser-ands foblibations, concenture are so
# enstrulies: the psranture s? ranhed protrtrouched, has itself in thathesths. heavene, for the conscience oneself righter bid co f
# Epoch 10/60
# 200285/200285 [==============================] - 110s 550us/step - loss: 1.4014
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "d such an ideal and clung to it so long?"
# d such an ideal and clung to it so long? in the strange and superficial strange, and the spirit of the most soul of the same delight to the strange that the strange, and the power of the personality as the personaling and soul of the strange, and the philosophers of the such a stronger the soul of the possible the strange, the special superficial more the soul of the conduct of the same soul of the same superficial that it is a personal
# ----- diversity: 0.5
# ----- Generating with seed: "d such an ideal and clung to it so long?"
# d such an ideal and clung to it so long? in the expedience and soul of the understand and fact, and the despenderal constitute which the popular to creates and moral creates for some and stance, which in its demand to be the higher and still the individual especially and really always all the considerative the instruted in the point of a perhaps the danger to be the strange of a perhaps and the deeped always perhaps have possible after
# ----- diversity: 1.0
# ----- Generating with seed: "d such an ideal and clung to it so long?"
# d such an ideal and clung to it so long? and not men-
# enources, free
# noti, stlevencientle: in the
# n.
#
#
# 15isaw
# asselts--but the in which the chuits of his very perhaps and if the most fundames and spuriding
# to him hive cspieteness ye for esent, that assuspent have
# one seem gonful merely experictally. the their practis is but european think, which is not or to usy means with one cannility--than ut "tools (and danger is their expertancous
# ----- diversity: 1.2
# ----- Generating with seed: "d such an ideal and clung to it so long?"
# d such an ideal and clung to it so long? in ordiial end. the upnetsing for
# our perrection lendind shumally; also the "stort eleven awaked behandebins, what which precisely necessary so oftenge! him aapaitionely perhaps hlooker. it cause wish subtletest cogntiandest requinare almosted thalless.=--this them to speap of sich in recognized "bur (even by almost free, its e
# europe.
#      wormssle allied. perhaps to yough
# in perforcal exartiat
# Epoch 11/60
#  34688/200285 [====>.........................] - ETA: 1:30 - loss: 1.3560
