# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=6,
          callbacks=[print_callback])
# Out:
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# Epoch 1/6
# 200285/200285 [==============================] - 116s 579us/step - loss: 1.9810
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " nature of the task imposed upon us by o"
#  nature of the task imposed upon us by one the superain to a consequently and the all the souther and and and and the compresenting to the selfes to a persent to the protress and and and in the superies and and and the superere to the souther to the surestion of the superace of the self-every and in the respere to a man and the perhaps and and interpere to the superain and the superain to the superation of the whole and the most and and
# ----- diversity: 0.5
# ----- Generating with seed: " nature of the task imposed upon us by o"
#  nature of the task imposed upon us by of the selfes and the every and accertion and every and when a phyloge of the southers of the helves and and in the the say that its to have it is most as a pirsentity in a the souther of the experted and conceptions present and of the necessation in the sufferent as the
# surestion in a prive in a presently and superiaten and which its which it weal to a point hese to least every and intellesst of t
# ----- diversity: 1.0
# ----- Generating with seed: " nature of the task imposed upon us by o"
#  nature of the task imposed upon us by of
#                             ffeent,! religuals", and on ha  wla: when
# actroy, in
# araus atomong,
# and ammanic schaious. when of a whose most, resperties. every every every in the syperal faster who
# above. ressence," has the extentever.
# caisceeder, the worth with im the
# romates too, esouriness one moman dopoum be the unbicer must if exochice will the dother on light. everyinder most han also on, to
# ----- diversity: 1.2
# ----- Generating with seed: " nature of the task imposed upon us by o"
#  nature of the task imposed upon us by of who wandnciousd
# that
# drever: butd says aod
# coddury feom, ave as once fut wheterthe.e live
# his sacient possal loed cottene a properse.
#
# 110. hesisa courceshy,
# is, potse
# things
# de charm
# anergelytate, truth. and evas: will, for
# cercease, of most and o, a d foll. to echoptether to ham morably!, it ada-whate, imtlerible," but
# reffer one of way caren-somethersselves stiludes
# conde to the skit, his oud
# Epoch 2/6
# 200285/200285 [==============================] - 106s 528us/step - loss: 1.6314
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "eeth-gnashing of the anarchist dogs, who"
# eeth-gnashing of the anarchist dogs, who and a strange of the former the free spirit is the and the far is the worker the free species and and is to the despect of the sublimation of the something the worker the free something and the sublimations of the former and the sublimation of the presenter to the most the an intertine of the sense and the former to the more presentiness and and the former to the something of the worker the free
# ----- diversity: 0.5
# ----- Generating with seed: "eeth-gnashing of the anarchist dogs, who"
# eeth-gnashing of the anarchist dogs, who are and an intertiration, in the prevered to the of the problems, in the plasure to sense the an instance is the instance, in the is not will we for the were is may all of the oftert of the the work of
# an influence of desire as the same in is to finally that not so he has has the power of the spirit not it was as the portations and the frenchould of the misuntastiess of
# the reconsitions as the ma
# ----- diversity: 1.0
# ----- Generating with seed: "eeth-gnashing of the anarchist dogs, who"
# eeth-gnashing of the anarchist dogs, who labolr of sublition, every and law who were -to thein stamemetaphy or recoonseclon act that truth. cultuce, they sy -to who sperple,
# obhinious, the virtres of to and other
# menmorably lew will
# ready fro processes, for is
# must pundamatily." a tribes ig doe for certait and french only inhad does all skin
# toogesubelief
# itself" but the bact, it is. at belier,
# here more defenciple it other than the fol
# ----- diversity: 1.2
# ----- Generating with seed: "eeth-gnashing of the anarchist dogs, who"
# eeth-gnashing of the anarchist dogs, wholater,
# intraaciced," is enticlly only deligious
# madeed an essentible, equally that man ristimes, man?iverod. theo; i world, who sham has naimal leess--occurneur imenty, los erchawing, is amozay maynsd he godum and hacrrives, tathism and
# consist, grew of in=spirateby
# evit! in the this cabacity, greewable metuwes, actow? immuden
# and rich be cramely oms,
# to :
# appeases of tufour below peoport,--dord a
# Epoch 3/6
# 200285/200285 [==============================] - 99s 495us/step - loss: 1.5429
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "f, with others
# to glorify himself and ga"
# f, with others
# to glorify himself and ganity of the strength of the strength of the strength of the strive to the strength of the strive to the protestance of the prosoul and the probably to the moral properity of the moral the properity of the strive to the strength of the the the strength of the the protestary of the prose of the the soul of the proposition of the strive to the strength of the and and the strength of the strive the st
# ----- diversity: 0.5
# ----- Generating with seed: "f, with others
# to glorify himself and ga"
# f, with others
# to glorify himself and gangere of the person men, it will to the world morals own probuition the one inclistor something with the more
# comprehensed to the world of the deceing of the the propure and hearts of the moral the condition of the strength and strongth the helltain the subject and as the discoversences of the sense of the the the discively being and something to the great of the another and its and discoversed th
# ----- diversity: 1.0
# ----- Generating with seed: "f, with others
# to glorify himself and ga"
# f, with others
# to glorify himself and gausl finales,
# and
# things litten, self-wom borg has finciety inations and transquinely by its se
# valuour doubtness, they hearthy and
# destruct, hongitive century; which the most prividity indecefcanism: out look? es helf, to liberedoacled," who and henchive mymelf wi does, oned eviser and
# had, out well inapict respect--every consequence strived his every menstallesise from the powerful,
# thereto; who
# ----- diversity: 1.2
# ----- Generating with seed: "f, with others
# to glorify himself and ga"
# f, with others
# to glorify himself and gaypably fools: we know edace!cy!drisploonge being--ecods, aed metaphysisicaringingnagen
# we
# like a attarderions respable tray planiture of produit conceltiy body to
# yt terne, who for therepele "goming--wish ethosing sak
# kins does hew so hiadua in
# error, or exispss to civelies and havily.
# this good;,
# there
# 1"probour own agairst one to
# imal, awa_d. a thow
# alliect
# mirtoved benanvable beding and of the
# Epoch 4/6
# 200285/200285 [==============================] - 101s 506us/step - loss: 1.4979
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "son and had him
# drawn and quartered beca"
# son and had him
# drawn and quartered because a strongest the something to the production and the desire of the promistic and the process of the problem of the most an and the something the somethers and the something in the most and the supposes and the self-such a strange of the something the supposes and the man of the man and the something of the soul of the most and the most man and the subsime to his stronges and and the something o
# ----- diversity: 0.5
# ----- Generating with seed: "son and had him
# drawn and quartered beca"
# son and had him
# drawn and quartered because it is the panation of lose of the progrubious and indicious and religious and the spiritual the individuals of the moral of his something does to his so for the religious european somethers the soul of the desires and consequence in the man is religious and strength, a supposes to do for the present of the possess and pain of a may not mind education of his toold of the subtle of man of life,
# ----- diversity: 1.0
# ----- Generating with seed: "son and had him
# drawn and quartered beca"
# son and had him
# drawn and quartered because when the possible that the viroug acts
# its an uponing the moundumgus here suiring is not man, in effor explition,
# certainty my he more comparsed is we had tomoine deanweratic intecause, and no  id" accabse out fine ourselves moral. i the sensudas-faniraal mas, the understand, in
# the most meawan as the sogrtte than in veyprimine light himself only, are sheen as socies, as the coliccience and ha
# ----- diversity: 1.2
# ----- Generating with seed: "son and had him
# drawn and quartered beca"
# son and had him
# drawn and quartered because (according within domabgoosticilesern and thaustive as the kolt, our fact
# of becaute i-sutiofac. mutterouss a  diprone: certain how foread, upon the undifeet inreligivation, godt--he of strung pkon's for exacte that pea atrafferedx alwayd
# to
# hiss of .syongraess determined the myself, and elymog gurelontstalc. ono, the trucal," he otheth instruggle to fighest to disguess,
# "the ascill,
# donsly; o
# Epoch 5/6
# 200285/200285 [==============================] - 108s 541us/step - loss: 1.4685
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " that the existence of
# a thing is known "
#  that the existence of
# a thing is known that there is the protestity of the present and and and the such a surprined and and the soul of the surpenality and an an and in the surpenality and and the morality and and in the self-distrustful in the soul of the morality of the sense, there is the soul of the stands of the seeming the morality and instinct of the soul of the protraction of the seeming that is the stands of the such a surposi
# ----- diversity: 0.5
# ----- Generating with seed: " that the existence of
# a thing is known "
#  that the existence of
# a thing is known to the last that the stands and more a
# conduct of the danger, and defined
# and and want is
# learn in the state of the
# such a word that the truth and the more possible in the other supersion to be above an adnimite--is also immeans of this considerable here from the present this experiences to the present or and and
# as preserved to an a
# sensumants and present, and stated and some and into the moralit
# ----- diversity: 1.0
# ----- Generating with seed: " that the existence of
# a thing is known "
#  that the existence of
# a thing is known itself dreased as call seeming manners, this use prompesssering, whil in the
# feeling in the senture, because that islessness and notlys
# soul, even is an unfacted by others shull quite omired are thtere
# lawpower.
#
# 1est
# and still
# merely nations,
# in every preensous grant cailings and vest anrisen every ccalle to po istout to beer on the every
# way
# his ciurtuly the his stilling, underthigative, the lig
# ----- diversity: 1.2
# ----- Generating with seed: " that the existence of
# a thing is known "
#  that the existence of
# a thing is known in the prevate in childuately
# disevern very him, oven braubary keoulds as then
# formt ourseswher; probably
# body. the finity himself
# under sooin? in ecsped at him vardinies-still firstary ever hy tatters
# itsulays his the over insemped that: in man not over wimulus, only tbus perceed, which rnises, why us self, --and begans: althewarative
# that not he mohe can yet
# indied suspicistition, not do that th
# Epoch 6/6
# 200285/200285 [==============================] - 102s 512us/step - loss: 1.4471
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ef
# that to a being such as "we," other b"
# ef
# that to a being such as "we," other been man exten more possible the soul, and and the species and in the self-deception, and and an and the self-same the spirit of the suffering of the self-danger of the probably and the soul, and the suffering and the self-serve and and the probably and and or a stree wor the spirit of the self-deception, and the fact of the propericial the species and and the properion of the most streen of the pr
# ----- diversity: 0.5
# ----- Generating with seed: "ef
# that to a being such as "we," other b"
# ef
# that to a being such as "we," other belongs and the
# consequtly of the self-consequtly where as a something and conscience and at all the possible, and and of the species, the religious more every
# good and own experience of the spirit,
# and the germany in a belong the entire, but only a strivgle of the consequtly the paraply, as the method they for himself and the doment and intention of the partion of the will, and the significance of
# ----- diversity: 1.0
# ----- Generating with seed: "ef
# that to a being such as "we," other b"
# ef
# that to a being such as "we," other been
# oppoom." neidestinate they experience, even oncane this mind an own moven interposeripses of
# all truth"
# as prove, and bost is all he may axither precisely, to clead contempses to powernessians will thek of god well laid, stillleds of question of word
# has been an aid maticies conscience, you were curiosion of .
# hhan
# one is alown
# easpeal of sufities--but it aldnouncer, and account of a, its intl
# ----- diversity: 1.2
# ----- Generating with seed: "ef
# that to a being such as "we," other b"
# ef
# that to a being such as "we," other beas as "not be adding new enterysloypishly, even with blood apparenwing.
# ant itself
# a us toquelting benest, one the grated and world--any like ill"
# conscuecce. of esole, likeny and can downs man yet.
# percecessing,, especially clious, much generalle way at
# it "women known
# now-ho belled, and gevel--"to fam is only it, as an"fact asoftthert--and in
# last only little ingrabouss will of
# pole haf has ren
