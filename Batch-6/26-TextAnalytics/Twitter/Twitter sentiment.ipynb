# %%
import tweepy
from textblob import TextBlob
import csv


# Step 1 - Authenticate
consumer_key= 'PGKQuYtBwUa8ih5iBy80umlIj'
consumer_secret= 'u2I5mh4llehglJt05RSN2lXnpDxqiZT3dQ0yMnsi9VW5itY2IC'

access_token='103894086-gQyAd64U82fU1jNW9F0vyaasetqSr0VHyqzHuzET'
access_token_secret='Q6eAXmd1Qry9jq82OfmPPyeWIblwY7hnnwd97he7GZL2I'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets
public_tweets = api.search('@gnanakuthu')



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

for tweet in public_tweets:
    print(tweet.text)
        
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment, '\n')   
print("")

#get public tweet in list
sentance_to_analyse = [[tweet.text]for tweet in public_tweets]

#Make row of tweets
with open('sentiment.csv', 'w') as csvfile:
    file = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_ALL)
    file.writerow(['Tweet', 'Polarity'])
    file.writerows(sentance_to_analyse)

#perform sentiment analysis on tweets    
with open('sentiment.csv', 'r') as f:
    rows = csv.reader(f)
    sentiment_of_tweet = [["Positive"] if TextBlob(r[0]).sentiment.polarity >= 0 else ["Negative"] for r in rows]

'''
 csv doesnt support write column because variable-length lines are not really 
 supported on most filesystems. What you should do instead is collect all the 
 data in lists, then call zip() on them to transpose them after. 
'''
#collect data in list-[], tupple-()
data = [(sentance_to_analyse),(sentiment_of_tweet)]
zipp = zip(*data)
#print(zipp)

#write tweet and its sentiment     
with open('sentiment.csv', 'w') as csvfile:
    file = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_ALL)
    
    file.writerow(['Tweet', 'Polarity'])
    file.writerows(zipp)
# Out:
# @PRJanarthanan @Gods_Rulee @Muppatimoonu @atgram @icloud_walker @vinoth827 @ssuba_18 @BlitzkriegKK @thanga_magal… https://t.co/6X8hKM2TZ9
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Gods_Rulee @Muppatimoonu @atgram @kothayinselvan @icloud_walker @vinoth827 @ssuba_18 @BlitzkriegKK @thanga_magal… https://t.co/k7Fb5VXDkZ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Muppatimoonu @atgram @kothayinselvan @icloud_walker @vinoth827 @ssuba_18 @BlitzkriegKK @thanga_magal @Being_Silra… https://t.co/OxgQGYVUzl
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @atgram @Gods_Rulee @kothayinselvan @icloud_walker @vinoth827 @ssuba_18 @BlitzkriegKK @thanga_magal @Being_Silra… https://t.co/PqpCPkF9CU
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Gods_Rulee @Muppatimoonu @kothayinselvan @icloud_walker @vinoth827 @ssuba_18 @BlitzkriegKK @thanga_magal… https://t.co/snyQg45EKZ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Muppatimoonu @kothayinselvan @icloud_walker @vinoth827 @atgram @ssuba_18 @BlitzkriegKK @thanga_magal @Being_Silra… https://t.co/T64fFIzdR9
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @kothayinselvan @Gods_Rulee @icloud_walker @vinoth827 @atgram @ssuba_18 @BlitzkriegKK @thanga_magal @Being_Silra… https://t.co/HhQcvbozBI
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Gods_Rulee @icloud_walker @vinoth827 @atgram @ssuba_18 @BlitzkriegKK @Muppatimoonu @thanga_magal @Being_Silra… https://t.co/OEs6RIWb3A
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @icloud_walker @vinoth827 @atgram @kothayinselvan @ssuba_18 @BlitzkriegKK @Muppatimoonu @thanga_magal @Being_Silra… https://t.co/ox1D6NUmj7
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @PRJanarthanan @vinoth827 @atgram @kothayinselvan @BlitzkriegKK @Gods_Rulee @Muppatimoonu @thanga_magal… https://t.co/FtCu2gjnO2
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @icloud_walker @vinoth827 @atgram @kothayinselvan @ssuba_18 @BlitzkriegKK @Gods_Rulee @Muppatimoonu @thanga_magal… https://t.co/Q7WFJ7O1bP
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @icloud_walker: @vinoth827 @atgram @kothayinselvan @ssuba_18 @BlitzkriegKK @Gods_Rulee @Muppatimoonu @thanga_magal @Being_Silra @PRJanar…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @vinoth827 @atgram @kothayinselvan @ssuba_18 @BlitzkriegKK @Gods_Rulee @Muppatimoonu @thanga_magal @Being_Silra… https://t.co/cNfrI7w519
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @vinoth827 @atgram @kothayinselvan @ssuba_18 @BlitzkriegKK @Gods_Rulee @Muppatimoonu @thanga_magal @Being_Silra… https://t.co/OaeS7WhY1o
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @vinoth827 @atgram @kothayinselvan @ssuba_18 @BlitzkriegKK @Gods_Rulee @Muppatimoonu @thanga_magal @Being_Silra… https://t.co/aKMbz7EdiR
# Sentiment(polarity=0.0, subjectivity=0.0)
