# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline

# %%
train = pd.read_csv("Train_UWu5bXk.csv")
test = pd.read_csv("Test_u94Q5KV.csv")
sample_submit = pd.read_csv("SampleSubmission_TmnO39y.csv")

# %%
sample_submit.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049                NaN
# 1           FDW14            OUT017                NaN
# 2           NCN55            OUT010                NaN
# 3           FDQ58            OUT017                NaN
# 4           FDY38            OUT027                NaN

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
train.columns.difference(test.columns)
# Out:
# Index(['Item_Outlet_Sales'], dtype='object')

# %%
print("train size :",train.shape)
print("test size :",test.shape)
# Out:
# train size : (8523, 12)
# test size : (5681, 11)

# %%
train["source"] = "train"
test["source"] = "test"

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %%
dataf = pd.concat([train,test],axis=0,sort=False)

# %%
dataf.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14204 entries, 0 to 5680
# Data columns (total 13 columns):
# Item_Identifier              14204 non-null object
# Item_Weight                  11765 non-null float64
# Item_Fat_Content             14204 non-null object
# Item_Visibility              14204 non-null float64
# Item_Type                    14204 non-null object
# Item_MRP                     14204 non-null float64
# Outlet_Identifier            14204 non-null object
# Outlet_Establishment_Year    14204 non-null int64
# Outlet_Size                  10188 non-null object
# Outlet_Location_Type         14204 non-null object
# Outlet_Type                  14204 non-null object
# Item_Outlet_Sales            8523 non-null float64
# source                       14204 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.5+ MB

# %%
dataf.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
dataf.nunique()
# Out:
# Item_Identifier               1559
# Item_Weight                    415
# Item_Fat_Content                 5
# Item_Visibility              13006
# Item_Type                       16
# Item_MRP                      8052
# Outlet_Identifier               10
# Outlet_Establishment_Year        9
# Outlet_Size                      3
# Outlet_Location_Type             3
# Outlet_Type                      4
# Item_Outlet_Sales             3493
# source                           2
# dtype: int64

# %%
dataf.shape
# Out:
# (14204, 13)

# %%
dataf.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
import pandas_profiling
# Out:
# /anaconda3/envs/seq2seq/lib/python3.6/site-packages/pandas_profiling/plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/envs/seq2seq/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 112, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/asyncio/base_events.py", line 1434, in _run_once
#     handle._run()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 102, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2907, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-eaac7682333e>", line 4, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3049, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/anaconda3/envs/seq2seq/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/anaconda3/envs/seq2seq/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)

# %%
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>14 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14204 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>6.1% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>112.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Item_Identifier"><code>Item_Identifier</code></a> has a high cardinality: 1559 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Item_Outlet_Sales"><code>Item_Outlet_Sales</code></a> has 5681 / 40.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Item_Visibility"><code>Item_Visibility</code></a> has 879 / 6.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Item_Weight"><code>Item_Weight</code></a> has 2439 / 17.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Outlet_Size"><code>Outlet_Size</code></a> has 4016 / 28.3% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Item_Fat_Content">Item_Fat_Content<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>5</td>
#         </tr>

# %%
dataf["Item_Identifier"].value_counts()
# Out:
# FDL39    10
# NCP02    10
# FDM60    10
# FDH27    10
# NCV42    10
# DRH23    10
# FDG10    10
# FDZ47    10
# NCQ43    10
# FDY14    10
# FDA52    10
# FDE45    10
# FDL58    10
# FDT50    10
# FDP27    10
# NCS29    10
# FDK56    10
# FDG33    10
# FDZ45    10
# FDL09    10
# NCR42    10
# FDD14    10
# FDR48    10
# FDY35    10
# FDY08    10
# FDZ07    10
# FDI32    10
# FDT51    10
# FDU20    10
# FDO31    10
#          ..
# FDL28     8
# FDX33     8
# FDW57     8
# FDM01     8
# FDO04     8
# FDN33     8
# FDW08     8
# FDB36     8
# NCT17     8
# FDY43     8
# FDF50     8
# FDX25     8
# FDC29     8
# FDY25     8
# FDI52     8
# FDU16     8
# FDZ46     8
# FDO33     7
# FDH58     7
# NCW54     7
# FDL50     7
# DRN11     7
# FDM10     7
# FDM52     7
# FDX49     7
# FDI46     7
# FDM50     7
# NCL42     7
# FDR51     7
# FDS22     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
dataf["Item_Weight"] = dataf.groupby("Item_Identifier").Item_Weight.transform(lambda x : x.fillna(x.mean()))

# %%
dataf.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
dataf.Outlet_Size.value_counts()
# Out:
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
def applymode(x):
    a = x.mode()[0]
    print(a)
    return x.fillna(a)

# %%
dataf["Outlet_Size"]=dataf.groupby("Outlet_Type").Outlet_Size.transform(applymode)
# Out:
# Small
# Small
# Medium
# Medium

# %%
dataf["Outlet_Size"].value_counts()
# Out:
# Small     7996
# Medium    4655
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
dataf.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
dataf.Item_Visibility.value_counts()
# Out:
# 0.000000    879
# 0.076856      3
# 0.076841      3
# 0.077290      3
# 0.077169      3
# 0.076975      3
# 0.077011      3
# 0.076792      3
# 0.076483      3
# 0.046899      2
# 0.159844      2
# 0.135708      2
# 0.135944      2
# 0.072298      2
# 0.136008      2
# 0.136896      2
# 0.203401      2
# 0.081788      2
# 0.075049      2
# 0.058369      2
# 0.104784      2
# 0.080131      2
# 0.072411      2
# 0.024635      2
# 0.052069      2
# 0.079968      2
# 0.179192      2
# 0.079806      2
# 0.121767      2
# 0.080625      2
#            ...
# 0.013147      1
# 0.098790      1
# 0.073397      1
# 0.137756      1
# 0.017937      1
# 0.105126      1
# 0.044156      1
# 0.141639      1
# 0.094411      1
# 0.074883      1
# 0.039236      1
# 0.044497      1
# 0.051147      1
# 0.175061      1
# 0.039034      1
# 0.077508      1
# 0.078943      1
# 0.077170      1
# 0.042959      1
# 0.013173      1
# 0.069939      1
# 0.011305      1
# 0.069042      1
# 0.012216      1
# 0.064142      1
# 0.209684      1
# 0.019592      1
# 0.013530      1
# 0.008772      1
# 0.066817      1
# Name: Item_Visibility, Length: 13006, dtype: int64

# %%
dataf.loc[dataf.Item_Visibility==0.000000,"Item_Visibility"]=np.nan

# %%
dataf.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility               879
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
dataf["Item_Visibility"] = dataf.groupby("Item_Identifier").Item_Visibility.transform(lambda x : x.fillna(x.median()))

# %%
dataf.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
dataf.Item_Fat_Content.value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
dataf["Item_Fat_Content"] = dataf.Item_Fat_Content.replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'})

# %%
dataf.Item_Fat_Content.value_counts()
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %%
dataf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.022919
# 4              NCD19        8.930          Low Fat         0.013206
# 5              FDP36       10.395          Regular         0.091172
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10       19.000          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.121848
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# 13             FDS46       17.600          Regular         0.047257
# 14             FDF32       16.350          Low Fat         0.068024
# 15             FDP49        9.000          Regular         0.069089
# 16             NCB42       11.800          Low Fat         0.008596
# 17             FDP49        9.000          Regular         0.069196
# 18             DRI11        8.260          Low Fat         0.034238
# 19             FDU02       13.350          Low Fat         0.102492
# 20             FDN22       18.850          Regular         0.138190
# 21             FDW12        8.315          Regular         0.035400
# 22             NCB30       14.600          Low Fat         0.025698
# 23             FDC37       15.500          Low Fat         0.057557
# 24             FDR28       13.850          Regular         0.025896
# 25             NCD06       13.000          Low Fat         0.099887
# 26             FDV10        7.645          Regular         0.066693
# 27             DRJ59       11.650          Low Fat         0.019356
# 28             FDE51        5.925          Regular         0.161467
# 29             FDC14       14.500          Regular         0.072222
# ...              ...          ...              ...              ...
# 5651           FDD23        9.500          Regular         0.048645
# 5652           FDP32        6.650          Low Fat         0.087847
# 5653           FDO31        6.760          Regular         0.028977
# 5654           FDQ57        7.275          Low Fat         0.027991
# 5655           FDX32       15.100          Regular         0.099375
# 5656           FDC39        7.405          Low Fat         0.158425
# 5657           FDU55       16.200          Low Fat         0.035911
# 5658           FDL45       15.600          Low Fat         0.037656
# 5659           DRK37        5.000          Low Fat         0.044073
# 5660           FDK22        9.800          Low Fat         0.026065
# 5661           DRG37       16.200          Low Fat         0.019418
# 5662           FDK22        9.800          Low Fat         0.026234
# 5663           DRH36       16.200          Low Fat         0.033516
# 5664           DRC36       13.000          Regular         0.045168
# 5665           DRE03       19.600          Low Fat         0.024110
# 5666           FDF34        9.300          Regular         0.014019
# 5667           FDZ22        9.395          Low Fat         0.045270
# 5668           FDC44       15.600          Low Fat         0.288892
# 5669           FDN31       11.500          Low Fat         0.072529
# 5670           FDO03       10.395          Regular         0.037092
# 5671           FDA01       15.000          Regular         0.054463
# 5672           NCH42        6.860          Low Fat         0.036594
# 5673           FDF46        7.070          Low Fat         0.094053
# 5674           DRL35       15.700          Low Fat         0.030704
# 5675           FDW46       13.000          Regular         0.070411
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.084897
# 5680           FDU37        9.500          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 6               Snack Foods   57.6588            OUT013
# 7               Snack Foods  107.7622            OUT027
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 10    Fruits and Vegetables   45.5402            OUT049
# 11                    Dairy  144.1102            OUT046
# 12    Fruits and Vegetables  145.4786            OUT049
# 13              Snack Foods  119.6782            OUT046
# 14    Fruits and Vegetables  196.4426            OUT013
# 15                Breakfast   56.3614            OUT046
# 16       Health and Hygiene  115.3492            OUT018
# 17                Breakfast   54.3614            OUT049
# 18              Hard Drinks  113.2834            OUT027
# 19                    Dairy  230.5352            OUT035
# 20              Snack Foods  250.8724            OUT013
# 21             Baking Goods  144.5444            OUT027
# 22                Household  196.5084            OUT035
# 23             Baking Goods  107.6938            OUT019
# 24             Frozen Foods  165.0210            OUT046
# 25                Household   45.9060            OUT017
# 26              Snack Foods   42.3112            OUT035
# 27              Hard Drinks   39.1164            OUT013
# 28                    Dairy   45.5086            OUT010
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 5651          Starchy Foods  186.1898            OUT013
# 5652  Fruits and Vegetables  126.7678            OUT045
# 5653  Fruits and Vegetables   80.2960            OUT035
# 5654            Snack Foods  144.5760            OUT013
# 5655  Fruits and Vegetables  143.6786            OUT027
# 5656                  Dairy  207.8296            OUT027
# 5657  Fruits and Vegetables  261.3278            OUT046
# 5658            Snack Foods  123.4704            OUT013
# 5659            Soft Drinks  188.8530            OUT049
# 5660            Snack Foods  215.3850            OUT013
# 5661            Soft Drinks  155.7972            OUT027
# 5662            Snack Foods  214.3850            OUT017
# 5663            Soft Drinks   72.8696            OUT018
# 5664            Soft Drinks  173.4054            OUT018
# 5665                  Dairy   46.0718            OUT027
# 5666            Snack Foods  196.9084            OUT046
# 5667            Snack Foods   82.1250            OUT046
# 5668  Fruits and Vegetables  115.1518            OUT010
# 5669  Fruits and Vegetables  188.0530            OUT027
# 5670                   Meat  229.4352            OUT017
# 5671                 Canned   59.5904            OUT049
# 5672              Household  231.1010            OUT049
# 5673            Snack Foods  116.0834            OUT018
# 5674            Hard Drinks   43.2770            OUT046
# 5675            Snack Foods   63.4484            OUT049
# 5676            Snack Foods  141.3154            OUT046
# 5677          Starchy Foods  169.1448            OUT018
# 5678     Health and Hygiene  118.7440            OUT045
# 5679                 Canned  214.6218            OUT017
# 5680                 Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998       Small               Tier 3
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# 6                          1987        High               Tier 3
# 7                          1985      Medium               Tier 3
# 8                          2002       Small               Tier 2
# 9                          2007       Small               Tier 2
# 10                         1999      Medium               Tier 1
# 11                         1997       Small               Tier 1
# 12                         1999      Medium               Tier 1
# 13                         1997       Small               Tier 1
# 14                         1987        High               Tier 3
# 15                         1997       Small               Tier 1
# 16                         2009      Medium               Tier 3
# 17                         1999      Medium               Tier 1
# 18                         1985      Medium               Tier 3
# 19                         2004       Small               Tier 2
# 20                         1987        High               Tier 3
# 21                         1985      Medium               Tier 3
# 22                         2004       Small               Tier 2
# 23                         1985       Small               Tier 1
# 24                         1997       Small               Tier 1
# 25                         2007       Small               Tier 2
# 26                         2004       Small               Tier 2
# 27                         1987        High               Tier 3
# 28                         1998       Small               Tier 3
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 5651                       1987        High               Tier 3
# 5652                       2002       Small               Tier 2
# 5653                       2004       Small               Tier 2
# 5654                       1987        High               Tier 3
# 5655                       1985      Medium               Tier 3
# 5656                       1985      Medium               Tier 3
# 5657                       1997       Small               Tier 1
# 5658                       1987        High               Tier 3
# 5659                       1999      Medium               Tier 1
# 5660                       1987        High               Tier 3
# 5661                       1985      Medium               Tier 3
# 5662                       2007       Small               Tier 2
# 5663                       2009      Medium               Tier 3
# 5664                       2009      Medium               Tier 3
# 5665                       1985      Medium               Tier 3
# 5666                       1997       Small               Tier 1
# 5667                       1997       Small               Tier 1
# 5668                       1998       Small               Tier 3
# 5669                       1985      Medium               Tier 3
# 5670                       2007       Small               Tier 2
# 5671                       1999      Medium               Tier 1
# 5672                       1999      Medium               Tier 1
# 5673                       2009      Medium               Tier 3
# 5674                       1997       Small               Tier 1
# 5675                       1999      Medium               Tier 1
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002       Small               Tier 2
# 5679                       2007       Small               Tier 2
# 5680                       2002       Small               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales source
# 0     Supermarket Type1          3735.1380  train
# 1     Supermarket Type2           443.4228  train
# 2     Supermarket Type1          2097.2700  train
# 3         Grocery Store           732.3800  train
# 4     Supermarket Type1           994.7052  train
# 5     Supermarket Type2           556.6088  train
# 6     Supermarket Type1           343.5528  train
# 7     Supermarket Type3          4022.7636  train
# 8     Supermarket Type1          1076.5986  train
# 9     Supermarket Type1          4710.5350  train
# 10    Supermarket Type1          1516.0266  train
# 11    Supermarket Type1          2187.1530  train
# 12    Supermarket Type1          1589.2646  train
# 13    Supermarket Type1          2145.2076  train
# 14    Supermarket Type1          1977.4260  train
# 15    Supermarket Type1          1547.3192  train
# 16    Supermarket Type2          1621.8888  train
# 17    Supermarket Type1           718.3982  train
# 18    Supermarket Type3          2303.6680  train
# 19    Supermarket Type1          2748.4224  train
# 20    Supermarket Type1          3775.0860  train
# 21    Supermarket Type3          4064.0432  train
# 22    Supermarket Type1          1587.2672  train
# 23        Grocery Store           214.3876  train
# 24    Supermarket Type1          4078.0250  train
# 25    Supermarket Type1           838.9080  train
# 26    Supermarket Type1          1065.2800  train
# 27    Supermarket Type1           308.9312  train
# 28        Grocery Store           178.4344  train
# 29        Grocery Store           125.8362  train
# ...                 ...                ...    ...
# 5651  Supermarket Type1                NaN   test
# 5652  Supermarket Type1                NaN   test
# 5653  Supermarket Type1                NaN   test
# 5654  Supermarket Type1                NaN   test
# 5655  Supermarket Type3                NaN   test
# 5656  Supermarket Type3                NaN   test
# 5657  Supermarket Type1                NaN   test
# 5658  Supermarket Type1                NaN   test
# 5659  Supermarket Type1                NaN   test
# 5660  Supermarket Type1                NaN   test
# 5661  Supermarket Type3                NaN   test
# 5662  Supermarket Type1                NaN   test
# 5663  Supermarket Type2                NaN   test
# 5664  Supermarket Type2                NaN   test
# 5665  Supermarket Type3                NaN   test
# 5666  Supermarket Type1                NaN   test
# 5667  Supermarket Type1                NaN   test
# 5668      Grocery Store                NaN   test
# 5669  Supermarket Type3                NaN   test
# 5670  Supermarket Type1                NaN   test
# 5671  Supermarket Type1                NaN   test
# 5672  Supermarket Type1                NaN   test
# 5673  Supermarket Type2                NaN   test
# 5674  Supermarket Type1                NaN   test
# 5675  Supermarket Type1                NaN   test
# 5676  Supermarket Type1                NaN   test
# 5677  Supermarket Type2                NaN   test
# 5678  Supermarket Type1                NaN   test
# 5679  Supermarket Type1                NaN   test
# 5680  Supermarket Type1                NaN   test
#
# [14204 rows x 13 columns]

# %%
dataf["Toatal_Years_Outlet"] = 2018-dataf["Outlet_Establishment_Year"]

# %%
dataf.drop(columns="Outlet_Establishment_Year",inplace=True)

# %%
dataf["Item_Identifier_Pattern"]=dataf['Item_Identifier'].apply(lambda x: x[0:2])

# %%
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14204 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>2.7% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.6 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>120.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Item_Identifier"><code>Item_Identifier</code></a> has a high cardinality: 1559 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Item_Outlet_Sales"><code>Item_Outlet_Sales</code></a> has 5681 / 40.0% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Item_Fat_Content">Item_Fat_Content<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>2</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (n)</th>
#             <td>0</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-6 collapse in" id="minifreqtable3183386628712330745">
#     <table class="mini freq">
#         <tr class="">
#     <th>L

# %%
dataf.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales', 'source',
#        'Toatal_Years_Outlet', 'Item_Identifier_Pattern'],
#       dtype='object')

# %%
dataf.Item_Type.value_counts()
# Out:
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64

# %%
dataf.loc[dataf.Outlet_Type.str.startswith("Supermarket"),"Outlet_Type_Pattern"]="SuperMarket"

# %%
dataf.loc[dataf.Outlet_Type.str.startswith("Grocery"),"Outlet_Type_Pattern"]="Grocery"

# %%
dataf.Outlet_Type_Pattern.value_counts()
# Out:
# SuperMarket    12399
# Grocery         1805
# Name: Outlet_Type_Pattern, dtype: int64

# %%
data_column_category = dataf.select_dtypes(exclude=[np.number]).columns

# %%
data_column_Integer = dataf.columns.difference(data_column_category)

# %%
dataf[data_column_category].nunique()
# Out:
# Item_Identifier            1559
# Item_Fat_Content              2
# Item_Type                    16
# Outlet_Identifier            10
# Outlet_Size                   3
# Outlet_Location_Type          3
# Outlet_Type                   4
# source                        2
# Item_Identifier_Pattern       3
# Outlet_Type_Pattern           2
# dtype: int64

# %%
dataf_one_hot = pd.get_dummies(dataf[data_column_category].drop(columns = "Item_Identifier"))

# %%
data_model = pd.concat([dataf["Outlet_Identifier"],dataf_one_hot,dataf["Item_Identifier"],dataf[data_column_Integer]],axis=1)

# %%
data_model.shape
# Out:
# (14204, 52)

# %%
train_modified = data_model.loc[data_model.source_train==1.0,:]

# %%
test_modified = data_model.loc[data_model.source_train==0.0,:]

# %%
test_modified.shape
# Out:
# (5681, 52)

# %%
train_modified.shape
# Out:
# (8523, 52)

# %%
test_modified.columns
# Out:
# Index(['Outlet_Identifier', 'Item_Fat_Content_Low Fat',
#        'Item_Fat_Content_Regular', 'Item_Type_Baking Goods',
#        'Item_Type_Breads', 'Item_Type_Breakfast', 'Item_Type_Canned',
#        'Item_Type_Dairy', 'Item_Type_Frozen Foods',
#        'Item_Type_Fruits and Vegetables', 'Item_Type_Hard Drinks',
#        'Item_Type_Health and Hygiene', 'Item_Type_Household', 'Item_Type_Meat',
#        'Item_Type_Others', 'Item_Type_Seafood', 'Item_Type_Snack Foods',
#        'Item_Type_Soft Drinks', 'Item_Type_Starchy Foods',
#        'Outlet_Identifier_OUT010', 'Outlet_Identifier_OUT013',
#        'Outlet_Identifier_OUT017', 'Outlet_Identifier_OUT018',
#        'Outlet_Identifier_OUT019', 'Outlet_Identifier_OUT027',
#        'Outlet_Identifier_OUT035', 'Outlet_Identifier_OUT045',
#        'Outlet_Identifier_OUT046', 'Outlet_Identifier_OUT049',
#        'Outlet_Size_High', 'Outlet_Size_Medium', 'Outlet_Size_Small',
#        'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
#        'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3', 'source_test', 'source_train',
#        'Item_Identifier_Pattern_DR', 'Item_Identifier_Pattern_FD',
#        'Item_Identifier_Pattern_NC', 'Outlet_Type_Pattern_Grocery',
#        'Outlet_Type_Pattern_SuperMarket', 'Item_Identifier', 'Item_MRP',
#        'Item_Outlet_Sales', 'Item_Visibility', 'Item_Weight',
#        'Toatal_Years_Outlet'],
#       dtype='object')

# %%
test_modified.drop(columns=['source_test', 'source_train','Item_Outlet_Sales'],inplace=True)
# Out:
# /anaconda3/envs/seq2seq/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
train_modified.drop(columns=['source_test', 'source_train'],inplace=True)
# Out:
# /anaconda3/envs/seq2seq/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
train_modified.to_csv("train_ready_for_model.csv",index=False)

# %%
test_modified.to_csv("test_ready_for_model.csv",index=False)

# %% [markdown]
# Modelling
